# %%
import nltk
import csv
import numpy as np
import re
import sys

# %%
# f = open('Dataset Canon S100 Reanotasi.csv','r')
# g = open('Dataset Canon S100 Reanotasi.csv','w')
# f_lines = f.readlines()
# for f_line in f_lines:
#     g_line = clean_str(f_line)
#     g.write(g_line)
#     g.write('\n')
# g.close()

# %%
data = []
datasimpan = []
with open('Dataset Canon S100 Reanotasi.csv') as csvfile:
    spamreader = csv.reader(csvfile)
    next(spamreader, None)
    for row in spamreader:
        data.append(row)
#     print(data[0])

for row in data:
    datasimpan.append(nltk.pos_tag(row[0].split()))
print(datasimpan)
# Out:
# [[('size[-2],camera[+2]##some', 'JJ'), ('people,', 'NN'), ('in', 'IN'), ('their', 'PRP$'), ('reviews,', 'NN'), ('complain', 'NN'), ('about', 'IN'), ('its', 'PRP$'), ('small', 'JJ'), ('size,', 'NN'), ('and', 'CC'), ('how', 'WRB'), ('it', 'PRP'), ("doesn't", 'VBZ'), ('compare', 'NN'), ('with', 'IN'), ('larger', 'JJR'), ('cameras.', 'NN')], [("camera[+3]##i'm", 'NN'), ('in', 'IN'), ('high', 'JJ'), ('school,', 'NN'), ('and', 'CC'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('perfect', 'JJ'), ('for', 'IN'), ('what', 'WP'), ('i', 'NN'), ('use', 'VBP'), ('it', 'PRP'), ('for,', 'VBZ'), ('carrying', 'VBG'), ('it', 'PRP'), ('around', 'IN'), ('in', 'IN'), ('my', 'PRP$'), ('pocket', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('can', 'MD'), ('take', 'VB'), ('pictures', 'NNS'), ('whenever', 'WRB'), ('i', 'NN'), ('want', 'VBP'), ('to,', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('friends', 'NNS'), ('and', 'CC'), ('of', 'IN'), ('funny', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('happen.', 'VBP')], [('car
# ...

# %%
for i in datasimpan:
    print(i)
# Out:
# [('size[-2],camera[+2]##some', 'JJ'), ('people,', 'NN'), ('in', 'IN'), ('their', 'PRP$'), ('reviews,', 'NN'), ('complain', 'NN'), ('about', 'IN'), ('its', 'PRP$'), ('small', 'JJ'), ('size,', 'NN'), ('and', 'CC'), ('how', 'WRB'), ('it', 'PRP'), ("doesn't", 'VBZ'), ('compare', 'NN'), ('with', 'IN'), ('larger', 'JJR'), ('cameras.', 'NN')]
# [("camera[+3]##i'm", 'NN'), ('in', 'IN'), ('high', 'JJ'), ('school,', 'NN'), ('and', 'CC'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('perfect', 'JJ'), ('for', 'IN'), ('what', 'WP'), ('i', 'NN'), ('use', 'VBP'), ('it', 'PRP'), ('for,', 'VBZ'), ('carrying', 'VBG'), ('it', 'PRP'), ('around', 'IN'), ('in', 'IN'), ('my', 'PRP$'), ('pocket', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('can', 'MD'), ('take', 'VB'), ('pictures', 'NNS'), ('whenever', 'WRB'), ('i', 'NN'), ('want', 'VBP'), ('to,', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('friends', 'NNS'), ('and', 'CC'), ('of', 'IN'), ('funny', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('happen.', 'VBP')]
# ...

# %%
# datasimpan[0][1]
data_adj = 0
data_noun = 0
d_sifat = []
for i in datasimpan:
    for j in i:
#         print(j)
        if (j[1]) == 'NN' or (j[1]) == 'NNS':
            print('noun', j)
            data_noun += 1
        elif (j[1]) == 'JJ' or (j[1]) == 'JJS' or (j[1]) == 'JJR':
            print('adj', j)
            data_adj += 1
            d_sifat.append(j)
print(data_adj)
print(data_noun)
print(d_sifat)
# Out:
# adj ('size[-2],camera[+2]##some', 'JJ')
# noun ('people,', 'NN')
# noun ('reviews,', 'NN')
# noun ('complain', 'NN')
# adj ('small', 'JJ')
# noun ('size,', 'NN')
# noun ('compare', 'NN')
# adj ('larger', 'JJR')
# noun ('cameras.', 'NN')
# noun ("camera[+3]##i'm", 'NN')
# adj ('high', 'JJ')
# noun ('school,', 'NN')
# noun ('camera', 'NN')
# adj ('perfect', 'JJ')
# noun ('i', 'NN')
# noun ('pocket', 'NN')
# adj ('i', 'JJ')
# noun ('pictures', 'NNS')
# noun ('i', 'NN')
# noun ('to,', 'NN')
# noun ('friends', 'NNS')
# adj ('funny', 'JJ')
# noun ('things', 'NNS')
# adj ('card[-2]##the', 'JJ')
# noun ('thing', 'NN')
# adj ('i', 'JJ')
# adj ('small', 'JJ')
# noun ('size', 'NN')
# noun ('memory', 'NN')
# noun ('card', 'NN')
# noun ('it.', 'NN')
# noun ('##i', 'NNS')
# noun ('pictures', 'NNS')
# noun ('day', 'NN')
# adj ('i', 'JJ')
# noun ('room', 'NN')
# adj ('more', 'JJR')
# noun ('pictures', 'NNS')
# noun ('next,', 'NN')
# noun ('i', 'NN')
# adj ('enough', 'JJ')
# noun ('money', 'NN')
# ...

# %%
# data_tokenisasi = []
# datax = []
# for row in data:
#     data_tokenisasi.append(nltk.word_tokenize(row[0]))
# # data_tokenisasi 

# for row in data_tokenisasi:
#     datax.append(nltk.pos_tag(row))
# datax.append

# %%
new_dict = []
new_dict_NN = []
new_dict_JJ = []
x = {}
for i in datasimpan:
#     print(i)
    for j in i:
        x.update([j])
#         print(j[1])
# x

for k in x:
    print(x[k]) #mengetahui value dari setiap key
    if (x[k]) == 'NN' or (x[k]) == 'JJ' or (x[k]) == 'JJS' or (x[k]) == 'JJR' or (x[k]) == 'NNS':
        new_dict.append(k)
        
        print('masuk')
#         if (x[k]) == 'NN':
#             new_dict_NN.append([x[k]])
#         elif (x[k]) == 'JJ':
#             new_dict_JJ.append([x[k]])
    else:
        print('keluar')
# Out:
# JJ
# masuk
# NN
# masuk
# IN
# keluar
# PRP$
# keluar
# NN
# masuk
# VB
# keluar
# IN
# keluar
# PRP$
# keluar
# JJ
# masuk
# NN
# masuk
# CC
# keluar
# WRB
# keluar
# PRP
# keluar
# VBZ
# keluar
# NN
# masuk
# IN
# keluar
# JJR
# masuk
# NN
# masuk
# NN
# masuk
# JJ
# masuk
# NN
# masuk
# DT
# keluar
# NN
# masuk
# VBZ
# keluar
# JJ
# masuk
# IN
# keluar
# WP
# keluar
# JJ
# masuk
# NN
# masuk
# VBZ
# keluar
# NN
# masuk
# RP
# keluar
# PRP$
# keluar
# NN
# masuk
# RB
# keluar
# MD
# keluar
# VB
# keluar
# NNS
# masuk
# WRB
# keluar
# VB
# keluar
# NN
# masuk
# IN
# keluar
# NNS
# masuk
# JJ
# masuk
# NNS
# masuk
# DT
# keluar
# VBP
# keluar
# JJ
# masuk
# JJ
# masuk
# NN
# masuk
# VBP
# keluar
# IN
# keluar
# DT
# keluar
# NN
# masuk
# NNP
# keluar
# NNP
# keluar
# NN
# masuk
# NN
# masuk
# VBZ
# keluar
# NN
# masuk
# RB
# keluar
# VBP
# keluar
# TO
# keluar
# VB
# keluar
# IN
# keluar
# DT
# keluar
# NN
# masuk
# NN
# masuk
# RBR
# keluar
# NN
# masuk
# JJ
# masuk
# NN
# masuk
# ...

# %%
x.get("battery")
# Out:
# 'NN'

# %%
for k in new_dict:
    print(k)
# Out:
# size[-2],camera[+2]##some
# people,
# reviews,
# small
# size,
# compare
# larger
# cameras.
# camera[+3]##i'm
# high
# school,
# camera
# perfect
# i
# use
# carrying
# pocket
# pictures
# to,
# friends
# funny
# things
# card[-2]##the
# only
# thing
# size
# memory
# card
# it.
# day
# room
# next,
# enough
# money
# meg
# eye
# while.
# memory[-1],battery[-1]##a
# extra
# battery
# good
# picture[-2]##other
# dark
# nice
# i'd
# them,
# camera[+3]##i'd
# perfect.
# camera[+2]##ok,
# compact
# side
# size[+2],camera[+2]##i
# same
# reason
# many
# it,
# it--it's
# size.
# ##it
# small,
# it's
# hard
# camera.
# able
# pocket,
# durable.
# cover[+2],lens[+2]##there
# covering
# lens,
# lens
# scratched.
# picture
# quality[-2]##the
# quality
# me,
# first
# good--but
# wrong!
# quality[+3],size[+3],price[+3]##the
# outstanding
# its'
# price
# consideration).
# ##however,
# few
# about...
# off,
# battery.
# battery[-2]##this
# lithium
# battery,
# batteries
# inconvenient;
# ...

# %%
(new_dict_JJ)
# Out:
# []

# %%
import csv
from nltk.parse.stanford import StanfordDependencyParser
import nltk
import numpy as np

dependency_parser = StanfordDependencyParser(path_to_jar='stanford-parser/stanford-parser.jar', path_to_models_jar='stanford-parser/stanford-models.jar')

def pemisahtandapagar(row):
    line = ''.join(row)
    line = line.split('##')
    return line
def dp(yes):
#     x = {}
    parsernya = dependency_parser.raw_parse(yes[1])
    hasil = parsernya.__next__()
#     x = parsernya
#     print(hasil)
    return hasil
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: The StanfordDependencyParser will be deprecated
# Please use nltk.parse.corenlp.CoreNLPDependencyParser instead.

# %%
data = []
kamus_parser = []
file = open("copy.txt", "w")
with open('Dataset Canon S100 Reanotasi.csv') as csvfile:
    spamreader = csv.reader(csvfile)
    next(spamreader, None)
    for row in spamreader:
        data.append(row)
for row in data:
    yes = pemisahtandapagar(row)
    print(yes[1])
#     print("Dependency parser: ")
    kamus_parser.append(dp(yes))
# np.savetxt('hasil.csv', x, delimiter=',', fmt='%s')
# Out:
# some people, in their reviews, complain about its small size, and how it doesn't compare with larger cameras.  1.0
# i'm in high school, and this camera is perfect for what i use it for, carrying it around in my pocket so i can take pictures whenever i want to, of my friends and of funny things that happen.2.0
# the only thing i don't like is the small size (8 meg) memory card that comes with it.3.0
# i have to move pictures off of it every day so i have room for more pictures the next, and i don't have enough money to buy the 256 meg card that i've had my eye on for a while.4.0
# a larger memory card and extra battery are good things to buy.5.0
# other than that pictures taken in the dark are not as nice as i'd like them,
# i'd say that this camera is perfect.
# ok, not quite everything...but this camera is so compact that you will have it by your side when you need it.
# i bought this camera for the same reason many of you are considering it, or have already bought it--it's size.
# ...

# %%
parser_dict = {}
for i in range(kamus_parser):
    parser_dict.update(kamus_parser[banyak].nodes[i]['word'])
parser_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8e34158813be> in <module>()
#       1 parser_dict = {}
# ----> 2 for i in range(kamus_parser):
#       3     parser_dict.update(kamus_parser[banyak].nodes[i]['word'])
#       4 parser_dict
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
for i in kamus_parser:
    print(i)
    
# kamus_parser
# Out:
# defaultdict(<function DependencyGraph.__init__.<locals>.<lambda> at 0x1a15036ae8>,
#             {0: {'address': 0,
#                  'ctag': 'TOP',
#                  'deps': defaultdict(<class 'list'>, {'root': [1]}),
#                  'feats': None,
#                  'head': None,
#                  'lemma': None,
#                  'rel': None,
#                  'tag': 'TOP',
#                  'word': None},
#              1: {'address': 1,
#                  'ctag': 'DT',
#                  'deps': defaultdict(<class 'list'>, {'dep': [8]}),
#                  'feats': '_',
#                  'head': 0,
#                  'lemma': '_',
#                  'rel': 'root',
#                  'tag': 'DT',
#                  'word': 'some'},
#              2: {'address': 2,
#                  'ctag': 'NNS',
#                  'deps': defaultdict(<class 'list'>, {'nmod': [6]}),
#                  'feats': '_',
#                  'head': 8,
#                  'lemma': '_',
# ...

# %%
kamus_parser[2]
# Out:
# <DependencyGraph with 21 nodes>

# %%
kamus_parser[0].nodes
# Out:
# defaultdict(<function nltk.parse.dependencygraph.DependencyGraph.__init__.<locals>.<lambda>>,
#             {0: {'address': 0,
#               'ctag': 'TOP',
#               'deps': defaultdict(list, {'root': [1]}),
#               'feats': None,
#               'head': None,
#               'lemma': None,
#               'rel': None,
#               'tag': 'TOP',
#               'word': None},
#              1: {'address': 1,
#               'ctag': 'DT',
#               'deps': defaultdict(list, {'dep': [8]}),
#               'feats': '_',
#               'head': 0,
#               'lemma': '_',
#               'rel': 'root',
#               'tag': 'DT',
#               'word': 'some'},
#              2: {'address': 2,
#               'ctag': 'NNS',
#               'deps': defaultdict(list, {'nmod': [6]}),
#               'feats': '_',
#               'head': 8,
#               'lemma': '_',
#               'rel': 'nsubj',
#               'tag': 'NNS',
# ...

# %%
# print(kamus_parser[0].nodes)
kamus_baru = []


for banyak in range(len(kamus_parser)):
    for i in kamus_parser[banyak].nodes:
#         print(kamus_parser[banyak].nodes[i]['word'])
        kamus_baru.append(kamus_parser[banyak].nodes[i]['word'])
# cari = 'conj'
# kamus_baru = []
# [kamus_baru.append(kamus_parser[0].nodes[:]['word']) if cari in kamus_parser[0].nodes[:]['word']]

kamus_baru
# Out:
# [None,
#  'some',
#  'people',
#  'complain',
#  'in',
#  'reviews',
#  'their',
#  'about',
#  'size',
#  'its',
#  'small',
#  'and',
#  'how',
#  'compare',
#  'it',
#  'does',
#  "n't",
#  'with',
#  'cameras',
#  'larger',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'i',
#  'school',
#  "'m",
#  'in',
#  'high',
#  'and',
#  'this',
#  'camera',
#  'perfect',
#  'is',
#  'for',
#  'use',
#  'what',
#  'i',
#  'it',
#  'for',
#  'carrying',
#  'it',
#  'around',
#  'in',
#  'pocket',
#  'my',
#  'so',
#  'i',
#  'take',
#  'can',
#  'pictures',
#  'whenever',
#  'want',
#  'i',
#  'to',
#  'of',
#  'friends',
#  'my',
#  'and',
#  'of',
#  'things',
#  'funny',
#  'that',
#  'happen',
#  '.2.0',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'the',
#  'i',
#  'only',
#  'thing',
#  'like',
#  'do',
#  "n't",
#  'card',
#  'is',
#  'the',
#  'small',
#  'size',
#  '8',
#  'meg',
#  'memory',
#  'that',
#  'comes',
#  'with',
#  'it',
#  '.3.0',
# ...

# %%
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
x = {}
for e in d_sifat:
    if ((e) in positive_vocab):
        print(e, 'masuk')
        positive_vocab.append(e)
    elif (e) in negative_vocab:
        print(e, 'masuk')
        negative_vocab.append(e)
    elif ((e) not in positive_vocab) and ((e) not in negative_vocab):
        print(e, 'gamasuk')
positive_vocab
# Out:
# ('size[-2],camera[+2]##some', 'JJ') gamasuk
# ('small', 'JJ') gamasuk
# ('larger', 'JJR') gamasuk
# ('high', 'JJ') gamasuk
# ('perfect', 'JJ') gamasuk
# ('i', 'JJ') gamasuk
# ('funny', 'JJ') gamasuk
# ('card[-2]##the', 'JJ') gamasuk
# ('i', 'JJ') gamasuk
# ('small', 'JJ') gamasuk
# ('i', 'JJ') gamasuk
# ('more', 'JJR') gamasuk
# ('enough', 'JJ') gamasuk
# ('memory[-1],battery[-1]##a', 'JJ') gamasuk
# ('larger', 'JJR') gamasuk
# ('extra', 'JJ') gamasuk
# ('good', 'JJ') gamasuk
# ('nice', 'JJ') gamasuk
# ('perfect.', 'JJ') gamasuk
# ('compact', 'JJ') gamasuk
# ('same', 'JJ') gamasuk
# ('many', 'JJ') gamasuk
# ("it--it's", 'JJ') gamasuk
# ('small,', 'JJ') gamasuk
# ('hard', 'JJ') gamasuk
# ('small', 'JJ') gamasuk
# ('i', 'JJ') gamasuk
# ('able', 'JJ') gamasuk
# ('durable.', 'JJ') gamasuk
# ('small', 'JJ') gamasuk
# ('scratched.', 'JJ') gamasuk
# ('quality[-2]##the', 'JJ') gamasuk
# ('small', 'JJ') gamasuk
# ('good--but', 'JJ') gamasuk
# ('wrong!', 'JJ') gamasuk
# ...

# %%
# for i in range(kamus_parser):
#     if i[0].nodes[0] == 'NN':
#         print('benar')
#     else:
#         print('salah')

# %%
kamus_parser[0].nodes[0]['tag']
# Out:
# 'TOP'

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
filename = 'Dataset Canon S100 Reanotasi.csv'
test_subset= open(filename,"r")
# tes = word_tokenize(test_subset)


sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neu_word_list=[]
neg_word_list=[]

for word in test_subset:
#     print((sid.polarity_scores(word)['compound']))
    if (sid.polarity_scores(word)['compound']) >= 0.5:
        pos_word_list.append(word)
    elif (sid.polarity_scores(word)['compound']) <= -0.5:
        neg_word_list.append(word)
    else:
        neu_word_list.append(word)                

print('Positive :',pos_word_list)        
print('Neutral :',neu_word_list)    
print('Negative :',neg_word_list)
# Out:
# Positive : ['"camera[+3]##i\'m in high school, and this camera is perfect for what i use it for, carrying it around in my pocket so i can take pictures whenever i want to, of my friends and of funny things that happen."\n', "camera[+3]##i'd say that this camera is perfect.\n", '"picture quality[+3],size[+3],price[+3]##the picture quality of this camera is outstanding (taking its\' size and price into consideration)."\n', '"focus[+2]##the focus is great, though, if you are not taking a macro shot."\n', '"##if you are just looking for something to keep with you at all times, then this is a great camera choice."\n', 'picture[+3]##this wonderfully small digital camera produces fantastically good pictures printed on any decent photo-quality printer (with photo quality paper).\n', "##it will not replace your high-end 35mm slr but it's a great toy to keep near you at all times for snapshots.\n", 'camera[+3]##this is the best camera you can have for digital images if you want to:\n', 'softwa
# ...

# %%
import nltk.classify.util
import nltk
# from nltk.tokenize import sentence_tokenize
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
neutral_vocab = [ 'movie','the','sound','was','is','actors','did','know','words','not' ]
 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]
 
train_set = negative_features + positive_features + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 
 
# Predict
neg = 0
pos = 0

sentence = "good movie, and i like it"
sentence = sentence.lower()
words = sentence.split(' ')
for word in words:
    classResult = classifier.classify( word_feats(word))
    if classResult == 'neg':
        neg = neg + 1
    if classResult == 'pos':
        pos = pos + 1
 
print('Positive: ' + str(float(pos)/len(words)))
print('Negative: ' + str(float(neg)/len(words)))
# Out:
# Positive: 0.6666666666666666
# Negative: 0.16666666666666666

# %%
#purning conj
for row in data:
    datasimpan.append(nltk.pos_tag(row[0].split()))
datasimpan
# Out:
# [[('size[-2],camera[+2]##some', 'JJ'),
#   ('people,', 'NN'),
#   ('in', 'IN'),
#   ('their', 'PRP$'),
#   ('reviews,', 'NN'),
#   ('complain', 'NN'),
#   ('about', 'IN'),
#   ('its', 'PRP$'),
#   ('small', 'JJ'),
#   ('size,', 'NN'),
#   ('and', 'CC'),
#   ('how', 'WRB'),
#   ('it', 'PRP'),
#   ("doesn't", 'VBZ'),
#   ('compare', 'NN'),
#   ('with', 'IN'),
#   ('larger', 'JJR'),
#   ('cameras.', 'NN')],
#  [("camera[+3]##i'm", 'NN'),
#   ('in', 'IN'),
#   ('high', 'JJ'),
#   ('school,', 'NN'),
#   ('and', 'CC'),
#   ('this', 'DT'),
#   ('camera', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('for', 'IN'),
#   ('what', 'WP'),
#   ('i', 'NN'),
#   ('use', 'VBP'),
#   ('it', 'PRP'),
#   ('for,', 'VBZ'),
#   ('carrying', 'VBG'),
#   ('it', 'PRP'),
#   ('around', 'IN'),
#   ('in', 'IN'),
#   ('my', 'PRP$'),
#   ('pocket', 'NN'),
#   ('so', 'IN'),
#   ('i', 'JJ'),
#   ('can', 'MD'),
#   ('take', 'VB'),
#   ('pictures', 'NNS'),
#   ('whenever', 'WRB'),
#   ('i', 'NN'),
# ...

# %%
import nltk
import nltk.classify.util
from nltk.tokenize import PunktSentenceTokenizer, sent_tokenize, word_tokenize
from nltk import pos_tag
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names

p=[]

filename = "Dataset Canon S100 Reanotasi.csv"
data= open(filename,"r")
for line in data:
	a = word_tokenize(line)
	tags = pos_tag(a)
	p.append(a)

sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neu_word_list=[]
neg_word_list=[]

for x in p:
	for word in x:
	    if (sid.polarity_scores(word)['compound']) >= 0.5:
	        pos_word_list.append(word)
	    elif (sid.polarity_scores(word)['compound']) <= -0.5:
	        neg_word_list.append(word)
	    else:
	        neu_word_list.append(word)                

print('Positive :',pos_word_list)        
print('Neutral :',neu_word_list)    
print('Negative :',neg_word_list) 

def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = pos_word_list
negative_vocab = neg_word_list
neutral_vocab = neu_word_list

 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
neutral_features = [(word_feats(neu), 'neu') for neu in neutral_vocab]
 
train_set = negative_features + positive_features + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 
 
# Predict
neg = 0
pos = 0

sentence = "perfect and great camera"
# for j in data:
# 	sen = sent_tokenize(j)
sentence = sentence.lower()
words = sentence.split(' ')
for word in words:
    classResult = classifier.classify( word_feats(word))
    if classResult == 'neg':
        neg = neg + 1
    if classResult == 'pos':
        pos = pos + 1
 
print('Positive: ' + str(float(pos)/len(words)))
print('Negative: ' + str(float(neg)/len(words)))
# Out:
# Positive : ['perfect', 'perfect.', 'outstanding', 'great', 'great', 'wonderfully', 'great', 'best', 'great', 'gorgeous', 'superior', 'love', 'best', 'happy', 'great', 'wonderful', 'best', 'perfect', 'wonderful', 'wonderful', 'gorgeous', 'love', 'great', 'great', 'fun', 'happy', 'great', 'great', 'great', 'love', 'excellent', 'perfect', 'great', 'excellent', 'love', 'perfect', 'great', 'beautiful', 'great', 'perfect', 'great', 'wonderful.', 'excellent', 'great.', 'great', 'wonderfully', 'love', 'perfect', 'great', 'love', 'superb', 'positives', 'beautiful', 'happy', 'fun']
# ...

# %%
import re
from nltk.tokenize import RegexpTokenizer

#tokenisasi
training_set = datasimpan
training_set_temp = []
# HEADER = 'klikdokter.com'

data_tokenisasi, hasil_tokenisasi = [], []
# tanda_baca = ['"','?','rs/',',','--','.','(',')',"'",'``',"''",'-','[',']','©','%','\\xa0','“','rn/','\\xa0sinus\\xa0dan','\\xa0tim','\\xa0social','nb/','rvs'] #untuk menghilangkan tanda baca

# Hapus header untuk tiap artikel
# for i in training_set:
#     temp = i.replace(HEADER, ' ')
#     training_set_temp.append(temp)
    
training_set = training_set_temp

tokenizer = RegexpTokenizer(r'\w+')
for i in training_set:
    data_tokenisasi.append(tokenizer.tokenize(i))
data_tokenisasi
# Out:
# []
